# %%
import pandas as pd

# %%
data = pd.read_csv("Tamil Love Songs Lyrics.csv")
data
# Out:
#                             பாடல்                      படம்  வருடம்  \
# 0               என்ன இந்த மாற்றமோ             கோரிப்பாளையம்    2010
# 1                   குறுமுகில்களை                சீதா ராமம்    2022
# 2                என்னை சாய்த்தாலே       என்றென்றும் புன்னகை    2013
# 3             ஒரு பாதி கதவு நீயடி                  தாண்டவம்    2012
# 4                        இரவாக நீ            இது என்ன மாயம்    2015
# ..                            ...                       ...     ...
# 95           அன்பே அன்பே கொல்லாதே                    ஜீன்ஸ்    1998
# 96          ஒரு தெய்வம் தந்த பூவே  கன்னத்தில் முத்தமிட்டாள்    2002
# 97          நெஞ்சினிலே நெஞ்சினிலே                     உயிரே    1998
# 98  முதல்முறை கிள்ளிப் பாா்த்தேன்                   சங்கமம்    1999
# 99           மின்னலே நீ வந்ததேனடி                  மே மாதம்    1994
#
#          இசையமைப்பாளர்                                       பாடல் வரிகள்  \
# 0          சபேஷ் முரளி  ஆண்: என்ன இந்த மாற்றமோ என் மனசு வழுக்குதே கண்ண...
# ...

# %%
data.isnull().sum()
# Out:
# பாடல்            0
# படம்             0
# வருடம்           0
# இசையமைப்பாளர்    0
# பாடல் வரிகள்     0
# பாடகர்கள்        0
# பாடலாசிரியர்     0
# உருவகம்          0
# உவமேயம்          0
# உவமானம்          0
# dtype: int64

# %%
data.to_json('Tamil Love Songs Lyrics.json', orient='records', lines=True, force_ascii=False)
